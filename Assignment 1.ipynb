# %%
Student_List=["Krishna","Priya","Ananya","Hardik","Harsh"]
print("Student List:"+str(Student_List))
# Out:
# Student List:['Krishna', 'Priya', 'Ananya', 'Hardik', 'Harsh']

# %%
Student_Tuple=("Krishna","Priya","Ananya","Hardik","Harsh")
print("Student Tuple:"+str(Student_Tuple))
# Out:
# Student Tuple:('Krishna', 'Priya', 'Ananya', 'Hardik', 'Harsh')

# %%
Student_Dictionary={"name": "krishna",
    "age": 18,
    "city": "pune"}
print("Student Dictionary:"+str(Student_Dictionary))
# Out:
# Student Dictionary:{'name': 'krishna', 'age': 18, 'city': 'pune'}

# %%
Student_Dictionary={"name": "krishna",
    "age": 18,
    "city": "pune"}

Student_Dictionary["College"]="MIT WPU"
print("Student Dictionary:"+str(Student_Dictionary))
# Out:
# Student Dictionary:{'name': 'krishna', 'age': 18, 'city': 'pune', 'College': 'MIT WPU'}

# %%
Student_Dictionary={"name": "krishna",
    "age": 18,
    "city": "pune"}
Student_Dictionary.pop("age")
print(Student_Dictionary)
# Out:
# {'name': 'krishna', 'city': 'pune'}

# %%
Student_Dictionary={"name": "krishna",
    "age": 18,
    "city": "pune"}
Student_Dictionary.update({"age":19, "city": "Mumbai"})
print(Student_Dictionary)
# Out:
# {'name': 'krishna', 'age': 19, 'city': 'Mumbai'}
